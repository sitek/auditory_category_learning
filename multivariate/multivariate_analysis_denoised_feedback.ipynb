# %%
import os
import json
import numpy as np
import nibabel as nib
import pandas as pd

from glob import glob

# %%
project_dir = os.path.join('/bgfs/bchandrasekaran/krs228/data/', 'FLT/')

bidsroot = os.path.join(project_dir, 'data_denoised')
deriv_dir = os.path.join(bidsroot, 'derivatives')
fmriprep_dir = os.path.join(deriv_dir, 'denoised_fmriprep-22.1.1')

nilearn_dir = os.path.join(deriv_dir, 'nilearn')
print(nilearn_dir)

mask_dir = os.path.join(project_dir, 'data_bids', 'derivatives', 'nilearn', 'masks')

task_list = ['tonecat']

# %%
participants_fpath = os.path.join(bidsroot, 'participants.tsv')
participants_df = pd.read_csv(participants_fpath, sep='\t')

# subjects to ignore (not fully processed, etc.)
ignore_subs = ['sub-FLT27',
               'sub-FLT07', # bad QA 11/14/23
               #'sub-FLT02', # missing resp_6 in run00 (pressing wrong keys)
               #'sub-FLT10', # MISSING 11/16/23
               #'sub-FLT01', 'sub-FLT16',  
               'sub-FLT15', 'sub-FLT18','sub-FLT22', 'sub-FLT24', # missing 12/20/23
               #'sub-FLT19', 'sub-FLT20',
               #'sub-FLT28', 'sub-FLT30',
              ]
participants_df.drop(participants_df[participants_df.participant_id.isin(ignore_subs)].index, inplace=True)

# re-sort by participant ID
participants_df.sort_values(by=['participant_id'], ignore_index=True, inplace=True)

# %%
participants_df

# %%
# create group-specific lists of subject IDs
sub_list_mand = list(participants_df.participant_id[participants_df.group=='Mandarin'])
sub_list_nman = list(participants_df.participant_id[participants_df.group=='non-Mandarin'])
sub_dict = {'Mandarin': sub_list_mand, 'non-Mandarin': sub_list_nman}

# %% [markdown]
# ## define anatomical masks

# %%
network_name = 'tian_subcortical_S3' # auditory

if network_name == 'auditory':
    roi_list = [
                'L-IC', 'L-MGN', 'L-HG', 'L-PT',  'L-PP', 'L-STGp', 'L-STGa', 'L-ParsOp', 'L-ParsTri',
                'R-IC', 'R-MGN', 'R-HG', 'R-PT',  'R-PP', 'R-STGp', 'R-STGa', 'R-ParsOp', 'R-ParsTri', 
               ]
elif network_name == 'aud-striatal':
    roi_list = ['L-Caud', 'L-Put', 'L-IC', 'L-MGN',
                'L-HG', 'L-PP', 'L-PT', 'L-STGa', 'L-STGp', 
                'L-ParsOp', 'L-ParsTri',
                'R-Caud', 'R-Put','R-IC', 'R-MGN',
                'R-HG', 'R-PP', 'R-PT', 'R-STGa', 'R-STGp', 
                'R-ParsOp', 'R-ParsTri',
               ]
elif network_name == 'tian_subcortical_S3':
    roi_list = [
                'CAU-DA-lh', 'CAU-VA-lh', 'pCAU-lh', 
                'PUT-DA-lh', 'PUT-DP-lh', 'PUT-VA-lh', 'PUT-VP-lh',
                'aGP-lh', 'pGP-lh', 'NAc-core-lh', 'NAc-shell-lh',
                'CAU-DA-rh', 'CAU-VA-rh', 'pCAU-rh', 
                'PUT-DA-rh', 'PUT-DP-rh', 'PUT-VA-rh', 'PUT-VP-rh',
                'aGP-rh', 'pGP-rh', 'NAc-core-rh', 'NAc-shell-rh', 
               ]

# %% [markdown]
# ## Define data and labels

# %%
def create_labels(stat_maps):
    import os
    from glob import glob
    from numpy.random import shuffle
    from copy import copy
    
    # 16 stimulus decoding
    #conditions_all = [os.path.basename(x)[-31:-18] for x in stat_maps] 
    conditions_all = ['_'.join(os.path.basename(x).split('_')[5:8]) for x in (stat_maps)]
    #print('all events: ', conditions_all[:10])

    # 4-category decoding
    conditions_tone = [os.path.basename(x).split('_')[5] for x in (stat_maps)]

    conditions_talker = [os.path.basename(x).split('_')[6] for x in (stat_maps)]
    
    # shuffled conditions
    conditions_shuffled = copy(conditions_tone)
    shuffle(conditions_shuffled)

    return conditions_tone, conditions_talker, conditions_all, conditions_shuffled

# %% [markdown]
# ## Decoding

# %% [markdown]
# ### scikit learn

# %%
def mask_fmri(fmri_niimgs, mask_filename, fwhm):
    from nilearn.maskers import NiftiMasker
    masker = NiftiMasker(mask_img=mask_filename, #runs=session_label,
                         smoothing_fwhm=fwhm, standardize=True,
                         #memory="nilearn_cache", memory_level=1
                        )
    fmri_masked = masker.fit_transform(fmri_niimgs)
    return fmri_masked, masker

# %%
# NOT CURRENTLY USED
def sub_region_svc(sub_id, mask_fpath, stat_maps, cv, fwhm=1.5, space_label='T1w'):
    from sklearn.svm import SVC
    from sklearn.model_selection import cross_val_score
    from sklearn.model_selection import permutation_test_score

    #print(sub_id)
    #print(os.path.basename(mask_fpath))
          
    conditions_tone, conditions_talker, conditions_all, conditions_shuffled = create_labels(stat_maps)

    # extract beta values from stat maps for given region of interest
    fmri_masked, masker = mask_fmri(stat_maps, mask_fpath, fwhm_sub)

    svc = SVC()

    tone_cv_scores = cross_val_score(svc, fmri_masked, conditions_tone, cv=cv)
    print("Tone SVC accuracy: {:.3f} with a standard deviation of {:.2f}".format(tone_cv_scores.mean(),tone_cv_scores.std()))

    talker_cv_scores = cross_val_score(svc, fmri_masked, conditions_talker, cv=cv)
    print("Talker SVC accuracy: {:.3f} with a standard deviation of {:.2f}".format(talker_cv_scores.mean(),talker_cv_scores.std()))

    null_cv_scores = permutation_test_score(svc, fmri_masked, conditions_tone, cv=cv, )[1]
    print("Permutation test score: {:.3f} with a standard deviation of {:.2f}".format(null_cv_scores.mean(),null_cv_scores.std()))
    
    #plot_confusion_matrix(fmri_masked, conditions_tone, mask_descrip, sub_id)
    #plot_confusion_matrix(fmri_masked, conditions_talker, mask_descrip, sub_id)
    
    return fmri_masked, tone_cv_scores, talker_cv_scores, null_cv_scores

# %% [markdown]
# #### Confusion matrix

# %%
def plot_confusion_matrix(X, y, mask_descrip, sub_id):
    import numpy as np
    import matplotlib.pyplot as plt

    from sklearn import svm, datasets
    from sklearn.model_selection import train_test_split
    from sklearn.metrics import ConfusionMatrixDisplay

    # Split the data into a training set and a test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,
                                                        random_state=0, stratify=y)

    # Run classifier, using a model that is too regularized (C too low) to see
    # the impact on the results
    classifier = svm.SVC(kernel="linear", ).fit(X_train, y_train)

    np.set_printoptions(precision=2)

    sub_title = 'sub-%s mask-%s'%(sub_id, mask_descrip)

    # Plot non-normalized confusion matrix
    titles_options = [("Confusion matrix, without normalization", None),
                      ("Normalized confusion matrix", "true"),]
    #for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
            classifier,
            X_test,
            y_test,
            #display_labels=class_names,
            cmap=plt.cm.Blues,
            #normalize='true', 
            )
    disp.ax_.set_title(sub_title)

    #print(title)
    #print(disp.confusion_matrix)

    #plt.show()
    
    return disp.confusion_matrix

# %% [markdown]
# #### Confusion matrices across regions

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt

fwhm_sub = 0.00
space_label = 'MNI152NLin2009cAsym'

model_desc = 'trial_models_LSS' # 'stimulus_per_run_LSS'
maptype = 'tstat'
split_design = 'random'

sub_list_temp = participants_df.participant_id.to_list()
sub_list = [x.split('-')[1] for x in sub_list_temp]

print(roi_list)
num_rois = len(roi_list)

# %%
# options: 'sound', 'resp', 'fb' (only available for non-Mandarin speakers)
contrast_label = 'fb'

# %%
out_dir = os.path.join(
                       bidsroot, 'derivatives', 'nilearn', 
                       'level-1_fwhm-%.02f'%fwhm_sub,
                       'level-1_den_mvpc-roi',
                       network_name,
                       f'contrast-{contrast_label}',)
os.makedirs(out_dir, exist_ok=True)

# %%
print(out_dir)

# %% [markdown]
# #### Run MVPC decoding per subject per ROI

# %%
print([os.path.basename(x) for x in stat_maps[:10]])

# %%
## TEST
for group_id, vals in sub_dict.items(): # ['FLT07'] # sub_list
    for sub_id in [vals[0]]:
        print(f'grp-{group_id} {sub_id}')
        sub_conf_mat = []

        fig, axs = plt.subplots(nrows=2, ncols=round(num_rois/2), 
                                figsize=(num_rois,6), dpi=200)

        nilearn_sub_dir = os.path.join(bidsroot, 'derivatives', 'nilearn', 
                                           'level-1_fwhm-%.02f'%fwhm_sub, 
                                           '%s_space-%s'%(sub_id, space_label))

        # grab stat maps
        stat_maps = sorted(glob(nilearn_sub_dir+f'/{model_desc}/run*/*{contrast_label}*map-{maptype}.nii.gz')) 
        print('# of stat maps: ', len(stat_maps))    
        #print(stat_maps)
        print([os.path.basename(x) for x in stat_maps[:10]])

        # generate condition labels based on filenames
        conditions_tone, conditions_talker, conditions_all, conditions_shuffled = create_labels(stat_maps)
        print(conditions_tone)

        for mx, mask_descrip in enumerate([roi_list[0]]):
            # define the mask for the region of interest
            print(mask_descrip)
            masks_dir = os.path.join(mask_dir, '%s'%sub_id, 'space-%s'%space_label)
            mask_fpath = glob(masks_dir + '/masks-*/' + '%s_space-%s_mask-%s.nii.gz'%(sub_id, space_label, mask_descrip))[0]

            fmri_masked, masker = mask_fmri(stat_maps, mask_fpath, fwhm_sub)

            # Split the data into a training set and a test set
            x, y = fmri_masked, conditions_tone
            if split_design == 'random':

                X_train, X_test, y_train, y_test = train_test_split(x,y, 
                                                                    test_size=0.25,
                                                                    random_state=0, 
                                                                    stratify=y)

# %%
mand_conf_mat = []
nman_conf_mat = []
for group_id, vals in sub_dict.items(): # ['FLT07'] # sub_list
    for sub_id in vals:
        print(f'grp-{group_id} {sub_id}')
        sub_conf_mat = []

        fig, axs = plt.subplots(nrows=2, ncols=round(num_rois/2), 
                                figsize=(num_rois,6), dpi=200)

        nilearn_sub_dir = os.path.join(bidsroot, 'derivatives', 'nilearn', 
                                           'level-1_fwhm-%.02f'%fwhm_sub, 
                                           '%s_space-%s'%(sub_id, space_label))

        # grab stat maps
        stat_maps = sorted(glob(nilearn_sub_dir+f'/{model_desc}/run*/*{contrast_label}*map-{maptype}.nii.gz')) 
        print('# of stat maps: ', len(stat_maps))    
        print(stat_maps)

        # generate condition labels based on filenames
        conditions_tone, conditions_talker, conditions_all, conditions_shuffled = create_labels(stat_maps)
        print(conditions_tone)

        for mx, mask_descrip in enumerate(roi_list):
            # define the mask for the region of interest
            print(mask_descrip)
            masks_dir = os.path.join(mask_dir, '%s'%sub_id, 'space-%s'%space_label)
            mask_fpath = glob(masks_dir + '/masks-*/' + '%s_space-%s_mask-%s.nii.gz'%(sub_id, space_label, mask_descrip))[0]

            fmri_masked, masker = mask_fmri(stat_maps, mask_fpath, fwhm_sub)

            # Split the data into a training set and a test set
            x, y = fmri_masked, conditions_tone
            if split_design == 'random':

                X_train, X_test, y_train, y_test = train_test_split(x,y, 
                                                                    test_size=0.25,
                                                                    random_state=0, 
                                                                    stratify=y)

            elif split_design == 'talker-sex':
                # split into male and female talker stimuli
                stim_m_indices = [i for i, s in enumerate(conditions_all) if any(xs in s for xs in ['aN', 'bN'])]
                stim_f_indices = [i for i, s in enumerate(conditions_all) if any(xs in s for xs in ['hN', 'iN'])]

                # train male, test female
                X_train = x[stim_m_indices]
                y_train = [y[i] for i in stim_m_indices]
                X_test = x[stim_f_indices]
                y_test = [y[i] for i in stim_f_indices]

            # Run classifier
            clf = svm.SVC(decision_function_shape='ovo').fit(X_train, y_train)
            y_pred = clf.predict(X_test)

            clf_acc = accuracy_score(y_test, y_pred)
            print(f'accuracy: {clf_acc:.04f}')

            ax = plt.subplot(2, num_rois/2, mx + 1)
            ax.set_title(f'{mask_descrip} \n acc = {clf_acc:.04f}')
            cm = confusion_matrix(y_test, y_pred, normalize='true',)
            #np.savetxt(os.path.join(out_dir, '{}_mask-{}_label-{}_split-{}_confusion_matrix.csv'.format(sub_id, mask_descrip, 'tone', split_design)), cm)
            
            cm_display = ConfusionMatrixDisplay.from_predictions(y_test, y_pred,
                                                                 ax=ax, 
                                                                  colorbar=False, 
                                                                  im_kw={'cmap':'Blues'},
                                                                  display_labels=['T1', 'T2', 'T3', 'T4'],
                                                                  include_values=False)
            

            sub_conf_mat.append(cm)
        # update figure suptitle
        fig.suptitle(f'group-{group_id} {sub_id}')
        # better spacing
        fig.tight_layout()

        #fig_fname = f'grp-{group_id}_{sub_id}_auditory_label-tone_split-{split_design}_confusion_matrices.png'
        fig.savefig(os.path.join(out_dir, fig_fname))

        # append to group list
        if sub_id in sub_list_mand:
            mand_conf_mat.append(sub_conf_mat)
        elif sub_id in sub_list_nman:
            nman_conf_mat.append(sub_conf_mat)
# Out:
# grp-Mandarin sub-FLT03
# # of stat maps:  275
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial10_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial11_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial12_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial13_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial14_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial15_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial16_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial17_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial18_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial19_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial1_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial20_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial21_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI152NLin2009cAsym_contrast-fb_correct_trial22_run00_model-LSS_map-tstat.nii.gz', '/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT03_space-MNI152NLin2009cAsym/trial_models_LSS/run00/sub-FLT03_task-tonecat_fwhm-0.00_space-MNI ...
# ['correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'wrong', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'wrong', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'wrong', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'wrong', 'wrong', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'wrong', 'wrong', 'wrong', 'wrong', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'correct', 'wrong', 'wrong', 'wrong', 'wrong']
# CAU-DA-lh
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [53], in <cell line: 3>()
#      27 masks_dir = os.path.join(mask_dir, '%s'%sub_id, 'space-%s'%space_label)
#      28 mask_fpath = glob(masks_dir + '/masks-*/' + '%s_space-%s_mask-%s.nii.gz'%(sub_id, space_label, mask_descrip))[0]
# ---> 30 fmri_masked, masker = mask_fmri(stat_maps, mask_fpath, fwhm_sub)
#      32 # Split the data into a training set and a test set
#      33 x, y = fmri_masked, conditions_tone
#
# Input In [8], in mask_fmri(fmri_niimgs, mask_filename, fwhm)
#       2 from nilearn.maskers import NiftiMasker
#       3 masker = NiftiMasker(mask_img=mask_filename, #runs=session_label,
#       4                      smoothing_fwhm=fwhm, standardize=True,
#       5                      #memory="nilearn_cache", memory_level=1
#       6                     )
# ----> 7 fmri_masked = masker.fit_transform(fmri_niimgs)
#       8 return fmri_masked, masker
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/maskers/base_masker.py:289, in BaseMasker.fit_transform(self, X, y, confounds, sample_mask, **fit_params)
#     285         return self.fit(X, **fit_params
#     286                         ).transform(X, confounds=confounds,
#     287                                     sample_mask=sample_mask)
#     288     else:
# --> 289         return self.fit(**fit_params).transform(X,
#     290                                                 confounds=confounds,
#     291                                                 sample_mask=sample_mask
#     292                                                 )
#     293 else:
#     294     # fit method of arity 2 (supervised transformation)
#     295     if self.mask_img is None:
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/maskers/base_masker.py:233, in BaseMasker.transform(self, imgs, confounds, sample_mask)
#     230 self._check_fitted()
#     232 if confounds is None and not self.high_variance_confounds:
# --> 233     return self.transform_single_imgs(imgs,
#     234                                       confounds=confounds,
#     235                                       sample_mask=sample_mask)
#     237 # Compute high variance confounds if requested
#     238 all_confounds = []
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/maskers/nifti_masker.py:570, in NiftiMasker.transform_single_imgs(self, imgs, confounds, sample_mask, copy)
#     555 # Ignore the mask-computing params: they are not useful and will
#     556 # just invalid the cache for no good reason
#     557 # target_shape and target_affine are conveyed implicitly in mask_img
#     558 params = _utils.class_inspect.get_params(
#     559     self.__class__,
#     560     self,
#    (...)
#     567     ],
#     568 )
# --> 570 data = self._cache(
#     571     _filter_and_mask,
#     572     ignore=[
#     573         'verbose',
#     574         'memory',
#     575         'memory_level',
#     576         'copy',
#     577     ],
#     578     shelve=self._shelving,
#     579 )(
#     580     imgs,
#     581     self.mask_img_,
#     582     params,
#     583     memory_level=self.memory_level,
#     584     memory=self.memory,
#     585     verbose=self.verbose,
#     586     confounds=confounds,
#     587     sample_mask=sample_mask,
#     588     copy=copy,
#     589     dtype=self.dtype,
#     590 )
#     592 return data
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/joblib/memory.py:352, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     351 def __call__(self, *args, **kwargs):
# --> 352     return self.func(*args, **kwargs)
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/maskers/nifti_masker.py:85, in _filter_and_mask(imgs, mask_img_, parameters, memory_level, memory, verbose, confounds, sample_mask, copy, dtype)
#      66 """Extract representative time series using given mask.
#      67
#      68 Parameters
#    (...)
#      80
#      81 """
#      82 # Convert input to niimg to check shape.
#      83 # This must be repeated after the shape check because check_niimg will
#      84 # coerce 5D data to 4D, which we don't want.
# ---> 85 temp_imgs = _utils.check_niimg(imgs)
#      87 # Raise warning if a 3D niimg is provided.
#      88 if temp_imgs.ndim == 3:
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/_utils/niimg_conversions.py:283, in check_niimg(niimg, ensure_ndim, atleast_4d, dtype, return_iterator, wildcards)
#     280     if return_iterator:
#     281         return _iter_check_niimg(niimg, ensure_ndim=ensure_ndim,
#     282                                  dtype=dtype)
# --> 283     return concat_niimgs(niimg, ensure_ndim=ensure_ndim, dtype=dtype)
#     285 # Otherwise, it should be a filename or a SpatialImage, we load it
#     286 niimg = load_niimg(niimg, dtype=dtype)
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/_utils/niimg_conversions.py:474, in concat_niimgs(niimgs, dtype, ensure_ndim, memory, memory_level, auto_resample, verbose)
#     471 for niimg in literator:
#     472     # We check the dimensionality of the niimg
#     473     try:
# --> 474         niimg = check_niimg(niimg, ensure_ndim=ndim)
#     475     except DimensionError as exc:
#     476         # Keep track of the additional dimension in the error
#     477         exc.increment_stack_counter()
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/_utils/niimg_conversions.py:286, in check_niimg(niimg, ensure_ndim, atleast_4d, dtype, return_iterator, wildcards)
#     283     return concat_niimgs(niimg, ensure_ndim=ensure_ndim, dtype=dtype)
#     285 # Otherwise, it should be a filename or a SpatialImage, we load it
# --> 286 niimg = load_niimg(niimg, dtype=dtype)
#     288 if ensure_ndim == 3 and len(niimg.shape) == 4 and niimg.shape[3] == 1:
#     289     # "squeeze" the image.
#     290     data = _safe_get_data(niimg)
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/_utils/niimg.py:131, in load_niimg(niimg, dtype)
#     128 niimg = stringify_path(niimg)
#     129 if isinstance(niimg, str):
#     130     # data is a filename, we load it
# --> 131     niimg = nibabel.load(niimg)
#     132 elif not isinstance(niimg, nibabel.spatialimages.SpatialImage):
#     133     raise TypeError("Data given cannot be loaded because it is"
#     134                     " not compatible with nibabel format:\n"
#     135                     + _repr_niimgs(niimg, shorten=True))
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nibabel/loadsave.py:50, in load(filename, **kwargs)
#      48 sniff = None
#      49 for image_klass in all_image_classes:
# ---> 50     is_valid, sniff = image_klass.path_maybe_image(filename, sniff)
#      51     if is_valid:
#      52         img = image_klass.from_filename(filename, **kwargs)
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nibabel/filebasedimages.py:507, in FileBasedImage.path_maybe_image(klass, filename, sniff, sniff_max)
#     505 if sniff is not None and len(sniff[0]) < klass._meta_sniff_len:
#     506     sniff = None
# --> 507 sniff = klass._sniff_meta_for(filename,
#     508                               max(klass._meta_sniff_len, sniff_max),
#     509                               sniff)
#     510 if sniff is None or len(sniff[0]) < klass._meta_sniff_len:
#     511     return False, sniff
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nibabel/filebasedimages.py:456, in FileBasedImage._sniff_meta_for(klass, filename, sniff_nbytes, sniff)
#     454 # Attempt to sniff from metadata location
#     455 try:
# --> 456     with ImageOpener(meta_fname, 'rb') as fobj:
#     457         binaryblock = fobj.read(sniff_nbytes)
#     458 except IOError:
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nibabel/openers.py:113, in Opener.__init__(self, fileish, *args, **kwargs)
#     110 # Clear keep_open hint if it is not relevant for the file type
#     111 else:
#     112     kwargs.pop('keep_open', None)
# --> 113 self.fobj = opener(fileish, *args, **kwargs)
#     114 self._name = fileish
#     115 self.me_opened = True
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nibabel/openers.py:49, in _gzip_open(filename, mode, compresslevel, keep_open)
#      43 def _gzip_open(filename, mode='rb', compresslevel=9, keep_open=False):
#      44
#      45     # use indexed_gzip if possible for faster read access.  If keep_open ==
#      46     # True, we tell IndexedGzipFile to keep the file handle open. Otherwise
#      47     # the IndexedGzipFile will close/open the file on each read.
#      48     if HAVE_INDEXED_GZIP and mode == 'rb':
# ---> 49         gzip_file = IndexedGzipFile(filename, drop_handles=not keep_open)
#      51     # Fall-back to built-in GzipFile
#      52     else:
#      53         gzip_file = gzip.GzipFile(filename, mode, compresslevel)
#
# File indexed_gzip/indexed_gzip.pyx:136, in indexed_gzip.indexed_gzip.IndexedGzipFile.__init__()
#
# File indexed_gzip/indexed_gzip.pyx:403, in indexed_gzip.indexed_gzip._IndexedGzipFile.__init__()
#
# File /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/contextlib.py:123, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     120     except StopIteration:
#     121         raise RuntimeError("generator didn't yield") from None
# --> 123 def __exit__(self, typ, value, traceback):
#     124     if typ is None:
#     125         try:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Group mean matrices

# %%
'''
mand_mean_cm = np.mean(mand_conf_mat, axis=0)
nman_mean_cm = np.mean(nman_conf_mat, axis=0)
'''

# %% [markdown]
# #### Read in pre-generated single-subject, single-ROI confusion matrices

# %%
mand_acc_dict = dict()
mand_cm_dict = dict()
for rx, roi in enumerate(roi_list):
    mand_acc = []
    subroi_list = []
    for sx, sub_id in enumerate(sub_list_mand):
        fpath = os.path.join(out_dir, #'level-1_mvpc-roi',
                             #f'{sub_id}_mask-{roi}_label-tone_split-{split_design}_confusion_matrix.csv',
                             f'{sub_id}_mask-{roi}_contrast-{contrast_label}_label-tone_confusion_matrix.csv',
                            )
        sr_data = np.genfromtxt(fpath)
        subroi_list.append(sr_data)
        
        sub_acc = np.diag(sr_data).mean()
        mand_acc.append(sub_acc)
    mand_subroi = np.array(subroi_list)
    mean_roi = mand_subroi.mean(axis=0)
    mand_cm_dict[roi] = mean_roi
    mand_acc_dict[roi] = mand_acc

nman_acc_dict = dict()
nman_cm_dict = dict()
for rx, roi in enumerate(roi_list):
    nman_acc = []
    subroi_list = []
    for sx, sub_id in enumerate(sub_list_nman):
        fpath = os.path.join(out_dir, #'level-1_mvpc-roi',
                             #f'{sub_id}_mask-{roi}_label-tone_split-{split_design}_confusion_matrix.csv',
                             f'{sub_id}_mask-{roi}_contrast-{contrast_label}_label-tone_confusion_matrix.csv',
                            )
        sr_data = np.genfromtxt(fpath)
        subroi_list.append(sr_data)
        
        sub_acc = np.diag(sr_data).mean()
        nman_acc.append(sub_acc)
    mand_subroi = np.array(subroi_list)
    mean_roi = mand_subroi.mean(axis=0)
    nman_cm_dict[roi] = mean_roi
    nman_acc_dict[roi] = nman_acc

# %% [markdown]
# #### Group-specific stats

# %%
from scipy import stats

mean_accs = []
p_vals = []
t_stats = []
print(f'Native Mandarin mean SVC accuracy')
for rx, roi in enumerate(roi_list):
    mand_roi_acc = np.array(mand_acc_dict[roi])
    mean_acc = mand_roi_acc.mean()
    
    ttest_res = stats.ttest_1samp(mand_roi_acc, popmean=0.25)
    print(f'mean SVC accuracy = {mean_acc:.04f} p = {ttest_res.pvalue:.04f} t = {ttest_res.statistic:.02f} region = {roi}')
    
    mean_accs.append(mean_acc)
    p_vals.append(ttest_res.pvalue)
    t_stats.append(ttest_res.statistic)

p_vals_adj = stats.false_discovery_control(p_vals)
for rx, roi in enumerate(roi_list):
    print(f'mean SVC accuracy = {mean_accs[rx]:.04f} t = {t_stats[rx]:.02f} FDR-corrected p = {p_vals_adj[rx]:.04f} region = {roi}')

mean_accs = []
p_vals = []
t_stats = []
print(f'Non-Mandarin mean SVC accuracy')
for rx, roi in enumerate(roi_list):
    nman_roi_acc = np.array(nman_acc_dict[roi])
    mean_acc = nman_roi_acc.mean()
    
    ttest_res = stats.ttest_1samp(nman_roi_acc, popmean=0.25)
    print(f'mean SVC accuracy = {mean_acc:.04f} p = {ttest_res.pvalue:.04f} t = {ttest_res.statistic:.02f} region = {roi}')
    
    mean_accs.append(mean_acc)
    p_vals.append(ttest_res.pvalue)
    t_stats.append(ttest_res.statistic)

p_vals_adj = stats.false_discovery_control(p_vals)
for rx, roi in enumerate(roi_list):
    print(f'mean SVC accuracy = {mean_accs[rx]:.04f} t = {t_stats[rx]:.02f} FDR-corrected p = {p_vals_adj[rx]:.04f} region = {roi}')
# Out:
# Native Mandarin mean SVC accuracy
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = CAU-DA-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = CAU-VA-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = pCAU-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = PUT-DA-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = PUT-DP-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = PUT-VA-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = PUT-VP-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = aGP-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = pGP-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = NAc-core-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = NAc-shell-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = CAU-DA-rh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = CAU-VA-rh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = pCAU-rh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = PUT-DA-rh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = PUT-DP-rh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = PUT-VA-rh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = PUT-VP-rh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = aGP-rh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = pGP-rh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = NAc-core-rh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = NAc-shell-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = CAU-DA-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = CAU-VA-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = pCAU-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = PUT-DA-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = PUT-DP-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = PUT-VA-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = PUT-VP-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = aGP-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = pGP-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = NAc-core-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = NAc-shell-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = CAU-DA-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = CAU-VA-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = pCAU-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = PUT-DA-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = PUT-DP-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = PUT-VA-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = PUT-VP-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = aGP-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = pGP-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = NAc-core-rh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = NAc-shell-rh
# Non-Mandarin mean SVC accuracy
# mean SVC accuracy = 0.5065 p = 0.0000 t = 39.18 region = CAU-DA-lh
# mean SVC accuracy = 0.4972 p = 0.0000 t = 89.00 region = CAU-VA-lh
# mean SVC accuracy = 0.4948 p = 0.0000 t = 47.46 region = pCAU-lh
# mean SVC accuracy = 0.4988 p = 0.0000 t = 209.00 region = PUT-DA-lh
# mean SVC accuracy = 0.5002 p = 0.0000 t = 1261.00 region = PUT-DP-lh
# mean SVC accuracy = 0.5123 p = 0.0000 t = 23.32 region = PUT-VA-lh
# mean SVC accuracy = 0.4942 p = 0.0000 t = 42.45 region = PUT-VP-lh
# mean SVC accuracy = 0.5000 p = 0.0000 t = inf region = aGP-lh
# mean SVC accuracy = 0.5024 p = 0.0000 t = 126.97 region = pGP-lh
# mean SVC accuracy = 0.5097 p = 0.0000 t = 26.71 region = NAc-core-lh
# mean SVC accuracy = 0.5085 p = 0.0000 t = 30.30 region = NAc-shell-lh
# mean SVC accuracy = 0.4954 p = 0.0000 t = 53.78 region = CAU-DA-rh
# mean SVC accuracy = 0.4980 p = 0.0000 t = 125.00 region = CAU-VA-rh
# mean SVC accuracy = 0.5040 p = 0.0000 t = 64.00 region = pCAU-rh
# mean SVC accuracy = 0.5026 p = 0.0000 t = 97.92 region = PUT-DA-rh
# mean SVC accuracy = 0.5012 p = 0.0000 t = 211.00 region = PUT-DP-rh
# mean SVC accuracy = 0.5013 p = 0.0000 t = 103.45 region = PUT-VA-rh
# mean SVC accuracy = 0.5016 p = 0.0000 t = 158.50 region = PUT-VP-rh
# mean SVC accuracy = 0.5060 p = 0.0000 t = 43.00 region = aGP-rh
# mean SVC accuracy = 0.5022 p = 0.0000 t = 115.55 region = pGP-rh
# mean SVC accuracy = 0.5030 p = 0.0000 t = 85.00 region = NAc-core-rh
# mean SVC accuracy = 0.5081 p = 0.0000 t = 31.73 region = NAc-shell-rh
# mean SVC accuracy = 0.5065 t = 39.18 FDR-corrected p = 0.0000 region = CAU-DA-lh
# mean SVC accuracy = 0.4972 t = 89.00 FDR-corrected p = 0.0000 region = CAU-VA-lh
# mean SVC accuracy = 0.4948 t = 47.46 FDR-corrected p = 0.0000 region = pCAU-lh
# mean SVC accuracy = 0.4988 t = 209.00 FDR-corrected p = 0.0000 region = PUT-DA-lh
# mean SVC accuracy = 0.5002 t = 1261.00 FDR-corrected p = 0.0000 region = PUT-DP-lh
# mean SVC accuracy = 0.5123 t = 23.32 FDR-corrected p = 0.0000 region = PUT-VA-lh
# mean SVC accuracy = 0.4942 t = 42.45 FDR-corrected p = 0.0000 region = PUT-VP-lh
# mean SVC accuracy = 0.5000 t = inf FDR-corrected p = 0.0000 region = aGP-lh
# mean SVC accuracy = 0.5024 t = 126.97 FDR-corrected p = 0.0000 region = pGP-lh
# mean SVC accuracy = 0.5097 t = 26.71 FDR-corrected p = 0.0000 region = NAc-core-lh
# mean SVC accuracy = 0.5085 t = 30.30 FDR-corrected p = 0.0000 region = NAc-shell-lh
# mean SVC accuracy = 0.4954 t = 53.78 FDR-corrected p = 0.0000 region = CAU-DA-rh
# mean SVC accuracy = 0.4980 t = 125.00 FDR-corrected p = 0.0000 region = CAU-VA-rh
# mean SVC accuracy = 0.5040 t = 64.00 FDR-corrected p = 0.0000 region = pCAU-rh
# mean SVC accuracy = 0.5026 t = 97.92 FDR-corrected p = 0.0000 region = PUT-DA-rh
# mean SVC accuracy = 0.5012 t = 211.00 FDR-corrected p = 0.0000 region = PUT-DP-rh
# mean SVC accuracy = 0.5013 t = 103.45 FDR-corrected p = 0.0000 region = PUT-VA-rh
# mean SVC accuracy = 0.5016 t = 158.50 FDR-corrected p = 0.0000 region = PUT-VP-rh
# mean SVC accuracy = 0.5060 t = 43.00 FDR-corrected p = 0.0000 region = aGP-rh
# mean SVC accuracy = 0.5022 t = 115.55 FDR-corrected p = 0.0000 region = pGP-rh
# mean SVC accuracy = 0.5030 t = 85.00 FDR-corrected p = 0.0000 region = NAc-core-rh
# mean SVC accuracy = 0.5081 t = 31.73 FDR-corrected p = 0.0000 region = NAc-shell-rh
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/scipy/stats/_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
l2_dir = os.path.join(nilearn_dir, 'level-2_den_mvpc-roi/')
os.makedirs(l2_dir, exist_ok=True)

# %%
# Mandarin-speaking participants
fig, axs = plt.subplots(nrows=2, ncols=round(num_rois/2), figsize=(num_rois,6), dpi=300)
fig.suptitle('Mandarin-speaking mean confusion matrices')

for mx, mask_descrip in enumerate(roi_list):
    ax = plt.subplot(2, num_rois/2, mx + 1)
    ConfusionMatrixDisplay(mand_cm_dict[mask_descrip],).plot(ax=ax, colorbar=False, 
                                                   im_kw={'cmap':'Blues', },
                                                   include_values=True)
    roi_mean = np.diag(mand_cm_dict[mask_descrip]).mean()
    ax.set_title(f'{mask_descrip}\n acc = {roi_mean:.04}')
    ax.set_xticklabels(['T1','T2','T3','T4'])
    ax.set_yticklabels(['T1','T2','T3','T4'])
# better spacing
fig.tight_layout()
fig.savefig(l2_dir + '/' + f'group-Mand_{network_name}_split-{split_design}_label-tone_incl-vals_confusion_matrices.png')

# Non-Mandarin-speaking participants
fig2, axs = plt.subplots(nrows=2, ncols=round(num_rois/2), figsize=(num_rois,6), dpi=300)
fig2.suptitle('Non-Mandarin-speaking mean confusion matrices')

for mx, mask_descrip in enumerate(roi_list):
    ax = plt.subplot(2, num_rois/2, mx + 1)
    ConfusionMatrixDisplay(nman_cm_dict[mask_descrip],).plot(ax=ax, colorbar=False, 
                                                   im_kw={'cmap':'Blues', },
                                                   include_values=True)
    roi_mean = np.diag(nman_cm_dict[mask_descrip]).mean()
    ax.set_title(f'{mask_descrip}\n acc = {roi_mean:.04}')
    ax.set_xticklabels(['T1','T2','T3','T4'])
    ax.set_yticklabels(['T1','T2','T3','T4'])
# better spacing
fig2.tight_layout()
#fig2.savefig(l2_dir + '/' + f'group-NMan_{network_name}_split-{split_design}_label-tone_incl-vals_confusion_matrices.png')

# %% [markdown]
# ### Combine all subjects

# %%
all_cm_dict = dict()
all_acc_dict = dict()
for rx, roi in enumerate(roi_list):
    all_acc = []
    subroi_list = []
    for sx, sub_id in enumerate(sub_list_mand+sub_list_nman):
        fpath = os.path.join(out_dir, #'level-1_mvpc-roi',
                             #f'{sub_id}_mask-{roi}_label-tone_split-{split_design}_confusion_matrix.csv',
                             f'{sub_id}_mask-{roi}_contrast-{contrast_label}_label-tone_confusion_matrix.csv',
                            )
        sr_data = np.genfromtxt(fpath)
        subroi_list.append(sr_data)
        
        sub_acc = np.diag(sr_data).mean()
        all_acc.append(sub_acc)
    all_subroi = np.array(subroi_list)
    mand_subroi = np.array(subroi_list)
    mean_roi = all_subroi.mean(axis=0)
    all_cm_dict[roi] = mean_roi
    all_acc_dict[roi] = all_acc
# Out:
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-CAU-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-CAU-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-pCAU-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-PUT-DA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-PUT-DP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-PUT-VA-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-PUT-VP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-aGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-pGP-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-NAc-core-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-NAc-core-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-NAc-core-lh_contrast-resp_label-tone_confusion_matrix.csv']
# ...
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-pGP-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-NAc-core-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT03_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT05_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT08_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT10_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT15_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT17_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT18_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT19_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT21_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT22_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT23_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT24_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT26_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT04_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT06_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT09_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT11_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT12_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT13_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT14_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT20_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT25_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT28_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']
# ['/bgfs/bchandrasekaran/krs228/data/FLT/data_denoised/derivatives/nilearn/level-1_fwhm-0.00/level-1_den_mvpc-roi/tian_subcortical_S3/contrast-resp/sub-FLT30_mask-NAc-shell-rh_contrast-resp_label-tone_confusion_matrix.csv']

# %%
from scipy import stats

mean_accs = []
p_vals = []
t_stats = []
print(f'All participants mean SVC accuracy')
for rx, roi in enumerate(roi_list):
    all_roi_acc = np.array(all_acc_dict[roi])
    mean_acc = all_roi_acc.mean()
    
    ttest_res = stats.ttest_1samp(all_roi_acc, popmean=0.25)
    print(f'mean SVC accuracy = {mean_acc:.04f} p = {ttest_res.pvalue:.04f} t = {ttest_res.statistic:.02f} region = {roi}')
    
    mean_accs.append(mean_acc)
    p_vals.append(ttest_res.pvalue)
    t_stats.append(ttest_res.statistic)

# FDR-corrected stats
p_vals_adj = stats.false_discovery_control(p_vals)
print('\nFDR-adjusted statistics')
for rx, roi in enumerate(roi_list):
    if p_vals_adj[rx] < 0.01:
        ast = '**'
    elif p_vals_adj[rx] < 0.05:
        ast = ' *'
    else:
        ast = '  '
    print(f'{ast}t = {t_stats[rx]:.02f} p = {p_vals_adj[rx]:.04f} region = {roi}')
# Out:
# All participants mean SVC accuracy
# mean SVC accuracy = 0.2656 p = 0.1612 t = 1.45 region = CAU-DA-lh
# mean SVC accuracy = 0.2655 p = 0.0915 t = 1.76 region = CAU-VA-lh
# mean SVC accuracy = 0.2731 p = 0.0067 t = 2.98 region = pCAU-lh
# mean SVC accuracy = 0.2677 p = 0.0168 t = 2.58 region = PUT-DA-lh
# mean SVC accuracy = 0.2491 p = 0.9037 t = -0.12 region = PUT-DP-lh
# mean SVC accuracy = 0.2716 p = 0.0707 t = 1.90 region = PUT-VA-lh
# mean SVC accuracy = 0.2547 p = 0.6606 t = 0.44 region = PUT-VP-lh
# mean SVC accuracy = 0.2411 p = 0.3143 t = -1.03 region = aGP-lh
# mean SVC accuracy = 0.2531 p = 0.7081 t = 0.38 region = pGP-lh
# mean SVC accuracy = 0.2650 p = 0.0187 t = 2.53 region = NAc-core-lh
# mean SVC accuracy = 0.2631 p = 0.1151 t = 1.64 region = NAc-shell-lh
# mean SVC accuracy = 0.2672 p = 0.0878 t = 1.78 region = CAU-DA-rh
# mean SVC accuracy = 0.2800 p = 0.0097 t = 2.82 region = CAU-VA-rh
# mean SVC accuracy = 0.2654 p = 0.1701 t = 1.42 region = pCAU-rh
# mean SVC accuracy = 0.2510 p = 0.9358 t = 0.08 region = PUT-DA-rh
# mean SVC accuracy = 0.2605 p = 0.3282 t = 1.00 region = PUT-DP-rh
# mean SVC accuracy = 0.2493 p = 0.9501 t = -0.06 region = PUT-VA-rh
# mean SVC accuracy = 0.2736 p = 0.0214 t = 2.47 region = PUT-VP-rh
# mean SVC accuracy = 0.2489 p = 0.9133 t = -0.11 region = aGP-rh
# mean SVC accuracy = 0.2473 p = 0.7771 t = -0.29 region = pGP-rh
# mean SVC accuracy = 0.2515 p = 0.8523 t = 0.19 region = NAc-core-rh
# mean SVC accuracy = 0.2591 p = 0.3130 t = 1.03 region = NAc-shell-rh
#
# FDR-adjusted statistics
#   t = 1.45 p = 0.3402 region = CAU-DA-lh
#   t = 1.76 p = 0.2516 region = CAU-VA-lh
#   t = 2.98 p = 0.0942 region = pCAU-lh
#   t = 2.58 p = 0.0942 region = PUT-DA-lh
#   t = -0.12 p = 0.9501 region = PUT-DP-lh
#   t = 1.90 p = 0.2516 region = PUT-VA-lh
#   t = 0.44 p = 0.9501 region = PUT-VP-lh
#   t = -1.03 p = 0.5157 region = aGP-lh
#   t = 0.38 p = 0.9501 region = pGP-lh
#   t = 2.53 p = 0.0942 region = NAc-core-lh
#   t = 1.64 p = 0.2813 region = NAc-shell-lh
#   t = 1.78 p = 0.2516 region = CAU-DA-rh
#   t = 2.82 p = 0.0942 region = CAU-VA-rh
#   t = 1.42 p = 0.3402 region = pCAU-rh
#   t = 0.08 p = 0.9501 region = PUT-DA-rh
#   t = 1.00 p = 0.5157 region = PUT-DP-rh
#   t = -0.06 p = 0.9501 region = PUT-VA-rh
#   t = 2.47 p = 0.0942 region = PUT-VP-rh
#   t = -0.11 p = 0.9501 region = aGP-rh
#   t = -0.29 p = 0.9501 region = pGP-rh
#   t = 0.19 p = 0.9501 region = NAc-core-rh
#   t = 1.03 p = 0.5157 region = NAc-shell-rh

# %%
# All participants
fig2, axs = plt.subplots(nrows=2, ncols=round(num_rois/2), figsize=(num_rois,6), dpi=300)
fig2.suptitle('All participants mean confusion matrices')

for mx, mask_descrip in enumerate(roi_list):
    ax = plt.subplot(2, num_rois/2, mx + 1)
    ConfusionMatrixDisplay(all_cm_dict[mask_descrip],).plot(ax=ax, colorbar=False, 
                                                   im_kw={'cmap':'Blues', },
                                                   include_values=True)
    roi_mean = np.diag(all_cm_dict[mask_descrip]).mean()
    ax.set_title(f'{mask_descrip}\n acc = {roi_mean:.04}')
    ax.set_xticklabels(['T1','T2','T3','T4'])
    ax.set_yticklabels(['T1','T2','T3','T4'])
# better spacing
fig2.tight_layout()
fig2.savefig(l2_dir + '/' + f'group-all_{network_name}_split-{split_design}_label-tone_incl-vals_confusion_matrices.png')

# %% [markdown]
# ### Compare with behavior

# %%
from scipy.stats import spearmanr

# %%
for sub_id in sub_list:
    print(sub_id)
    behav_cm = np.genfromtxt('behav_confusion_matrices/sub-{}_behav_confusion_matrix.csv'.format(sub_id))    
    behav_off_diag = behav_cm[np.where(~np.eye(behav_cm.shape[0],dtype=bool))]
    #print(behav_off_diag)
    for mx, mask_descrip in enumerate(roi_list):
        mask_cm = np.genfromtxt('striatal_confusion_matrices/sub-{}_mask-{}_label-{}_confusion_matrix.csv'.format(sub_id, mask_descrip, 'tone'))
        mask_off_diag = mask_cm[np.where(~np.eye(mask_cm.shape[0],dtype=bool))]
        #print(mask_off_diag)
        
        r, p = spearmanr(behav_off_diag, mask_off_diag)
        print('{} r = {:.03f} p = {:.03f}'.format(mask_descrip, r, p))
# Out:
# FLT01
# L-Caud r = -0.091 p = 0.779
# L-Put r = 0.674 p = 0.016
# R-Caud r = 0.522 p = 0.082
# R-Put r = 1.000 p = 0.000
# FLT03
# L-Caud r = 0.113 p = 0.727
# L-Put r = -0.199 p = 0.535
# R-Caud r = 0.739 p = 0.006
# R-Put r = 0.739 p = 0.006
# FLT05
# L-Caud r = 0.180 p = 0.575
# L-Put r = 0.158 p = 0.624
# R-Caud r = -0.199 p = 0.535
# R-Put r = -0.135 p = 0.676
# FLT07
# L-Caud r = nan p = nan
# L-Put r = nan p = nan
# R-Caud r = nan p = nan
# R-Put r = nan p = nan
# FLT08
# L-Caud r = nan p = nan
# L-Put r = nan p = nan
# R-Caud r = nan p = nan
# R-Put r = nan p = nan
# FLT10
# L-Caud r = -0.255 p = 0.424
# L-Put r = 0.604 p = 0.037
# R-Caud r = -0.174 p = 0.588
# R-Put r = -0.134 p = 0.677
# FLT02
# L-Caud r = 0.024 p = 0.940
# L-Put r = 0.297 p = 0.349
# R-Caud r = 0.381 p = 0.222
# R-Put r = 0.087 p = 0.787
# FLT04
# L-Caud r = 0.787 p = 0.002
# L-Put r = 0.547 p = 0.066
# R-Caud r = 0.795 p = 0.002
# R-Put r = 0.709 p = 0.010
# FLT06
# L-Caud r = 0.073 p = 0.822
# L-Put r = 0.032 p = 0.923
# R-Caud r = 0.198 p = 0.538
# R-Put r = 0.273 p = 0.390
# FLT09
# L-Caud r = 0.451 p = 0.142
# L-Put r = 0.868 p = 0.000
# R-Caud r = 0.681 p = 0.015
# R-Put r = 0.770 p = 0.003
# FLT11
# L-Caud r = 0.433 p = 0.160
# L-Put r = 0.042 p = 0.898
# R-Caud r = 0.525 p = 0.080
# R-Put r = 0.143 p = 0.658
# FLT12
# L-Caud r = 0.730 p = 0.007
# L-Put r = 0.627 p = 0.029
# R-Caud r = 0.730 p = 0.007
# R-Put r = 0.831 p = 0.001
# FLT13
# L-Caud r = 0.418 p = 0.176
# L-Put r = 0.425 p = 0.168
# R-Caud r = 0.210 p = 0.513
# R-Put r = 0.603 p = 0.038

# %%
# Out:
# '1.6.2'

# %% [markdown]
# ### ARCHIVE: Run pipeline

# %%
from sklearn.model_selection import KFold, StratifiedKFold

fwhm_sub = 0 # 1.5
space_label = 'MNI152NLin2009cAsym' #'T1w' 

cv = StratifiedKFold(n_splits=4)

# %%
#roi_list = list(roi_dict.keys())
print(roi_list)
# Out:
# ['L-CN', 'L-SOC', 'L-IC', 'L-MGN', 'R-CN', 'R-SOC', 'R-IC', 'R-MGN']

# %%
nilearn_sub_dir
# Out:
# '/bgfs/bchandrasekaran/krs228/data/FLT/data_bids_noIntendedFor/derivatives/nilearn/level-1_fwhm-0.00/sub-FLT01_space-MNI152NLin2009cAsym/trial_models'

# %%
cv_list_tone = []
cv_list_talker = []
cv_list_null = []
for sub_id in sub_list:
    print(sub_id)
    sub_tone = []
    sub_talker = []
    sub_null = []
    
    for mask_descrip in roi_list:
        # define the mask for the region of interest
        print(mask_descrip)
        masks_dir = os.path.join(nilearn_dir, 'masks', 'sub-%s'%sub_id, 'space-%s'%space_label, 'masks-subcort-aud', ) # 'masks-aparc'
        mask_fpath = os.path.join(masks_dir, 'sub-%s_space-%s_mask-%s.nii.gz'%(sub_id, space_label, mask_descrip))
        #mask_img = nib.load(mask_fpath)

        '''
        t1w_fpath = os.path.join(fmriprep_dir, 'sub-%s'%sub_id, 'anat', 
                                 'sub-%s_desc-preproc_T1w.nii.gz'%sub_id)
        print('T1w file path: ', t1w_fpath)
        brainmask_fpath = os.path.join(fmriprep_dir, 'sub-%s'%sub_id, 'anat', 
                                 'sub-%s_desc-brain_mask.nii.gz'%sub_id)
        print('brain mask file path: ', brainmask_fpath)
        '''
        nilearn_sub_dir = os.path.join(bidsroot, 'derivatives', 'nilearn', 
                                       'level-1_fwhm-%.02f'%fwhm_sub, 
                                       'sub-%s_space-%s'%(sub_id, space_label),
                                       'trial_models')

        stat_maps = sorted(glob(nilearn_sub_dir+'/run*/*di*nii.gz')) # run-specific stimulus beta maps
        #stat_maps = sorted(glob(nilearn_sub_dir+'/trial_models'+'/run*/*di*trial*nii.gz')) # run-specific trial beta maps
        #stat_maps = sorted(glob(nilearn_sub_dir+'/run-all/*di*beta.nii.gz')) # run-all
        print('# of stat maps: ', len(stat_maps))    

        fmri_masked, tone_cv_scores, \
            talker_cv_scores, null_cv_scores = sub_region_svc(sub_id, mask_fpath, stat_maps, cv, 
                                                              fwhm=fwhm_sub, space_label=space_label)
        sub_tone.append(tone_cv_scores)
        sub_talker.append(talker_cv_scores)
        sub_null.append(null_cv_scores)
    
    # append subject cv scores to overall list
    cv_list_tone.append(sub_tone)
    cv_list_talker.append(sub_talker)
    cv_list_null.append(sub_null)
# Out:
# FLT01
# L-CN
# # of stat maps:  64
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.344 with a standard deviation of 0.10
# Talker SVC accuracy: 0.266 with a standard deviation of 0.03
# Permutation test score: 0.244 with a standard deviation of 0.06
# L-SOC
# # of stat maps:  64
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.281 with a standard deviation of 0.03
# Talker SVC accuracy: 0.312 with a standard deviation of 0.04
# Permutation test score: 0.245 with a standard deviation of 0.06
# L-IC
# # of stat maps:  64
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.156 with a standard deviation of 0.09
# Talker SVC accuracy: 0.250 with a standard deviation of 0.04
# Permutation test score: 0.228 with a standard deviation of 0.06
# L-MGN
# # of stat maps:  64
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.172 with a standard deviation of 0.05
# Talker SVC accuracy: 0.266 with a standard deviation of 0.07
# Permutation test score: 0.229 with a standard deviation of 0.06
# R-CN
# # of stat maps:  64
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.219 with a standard deviation of 0.11
# Talker SVC accuracy: 0.203 with a standard deviation of 0.08
# Permutation test score: 0.248 with a standard deviation of 0.06
# R-SOC
# # of stat maps:  64
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.359 with a standard deviation of 0.16
# Talker SVC accuracy: 0.234 with a standard deviation of 0.09
# Permutation test score: 0.240 with a standard deviation of 0.07
# R-IC
# # of stat maps:  64
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.328 with a standard deviation of 0.15
# Talker SVC accuracy: 0.188 with a standard deviation of 0.08
# Permutation test score: 0.237 with a standard deviation of 0.06
# R-MGN
# # of stat maps:  64
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.344 with a standard deviation of 0.13
# Talker SVC accuracy: 0.266 with a standard deviation of 0.05
# Permutation test score: 0.234 with a standard deviation of 0.05
# FLT03
# L-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.354 with a standard deviation of 0.08
# Talker SVC accuracy: 0.240 with a standard deviation of 0.02
# Permutation test score: 0.244 with a standard deviation of 0.04
# L-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.281 with a standard deviation of 0.07
# Talker SVC accuracy: 0.281 with a standard deviation of 0.03
# Permutation test score: 0.246 with a standard deviation of 0.06
# L-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.354 with a standard deviation of 0.05
# Talker SVC accuracy: 0.187 with a standard deviation of 0.06
# Permutation test score: 0.220 with a standard deviation of 0.05
# L-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.344 with a standard deviation of 0.15
# Talker SVC accuracy: 0.323 with a standard deviation of 0.09
# Permutation test score: 0.212 with a standard deviation of 0.05
# R-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.458 with a standard deviation of 0.10
# Talker SVC accuracy: 0.219 with a standard deviation of 0.07
# Permutation test score: 0.232 with a standard deviation of 0.05
# R-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.198 with a standard deviation of 0.07
# Talker SVC accuracy: 0.229 with a standard deviation of 0.04
# Permutation test score: 0.233 with a standard deviation of 0.05
# R-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.292 with a standard deviation of 0.18
# Talker SVC accuracy: 0.260 with a standard deviation of 0.05
# Permutation test score: 0.216 with a standard deviation of 0.05
# R-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.302 with a standard deviation of 0.10
# Talker SVC accuracy: 0.219 with a standard deviation of 0.07
# Permutation test score: 0.230 with a standard deviation of 0.06
# FLT05
# L-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.240 with a standard deviation of 0.07
# Talker SVC accuracy: 0.250 with a standard deviation of 0.05
# Permutation test score: 0.241 with a standard deviation of 0.05
# L-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.250 with a standard deviation of 0.03
# Talker SVC accuracy: 0.188 with a standard deviation of 0.05
# Permutation test score: 0.239 with a standard deviation of 0.05
# L-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.406 with a standard deviation of 0.09
# Talker SVC accuracy: 0.302 with a standard deviation of 0.05
# Permutation test score: 0.242 with a standard deviation of 0.05
# L-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.417 with a standard deviation of 0.10
# Talker SVC accuracy: 0.229 with a standard deviation of 0.07
# Permutation test score: 0.217 with a standard deviation of 0.05
# R-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.365 with a standard deviation of 0.08
# Talker SVC accuracy: 0.281 with a standard deviation of 0.09
# Permutation test score: 0.228 with a standard deviation of 0.06
# R-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.281 with a standard deviation of 0.11
# Talker SVC accuracy: 0.177 with a standard deviation of 0.05
# Permutation test score: 0.238 with a standard deviation of 0.05
# R-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.354 with a standard deviation of 0.02
# Talker SVC accuracy: 0.250 with a standard deviation of 0.00
# Permutation test score: 0.227 with a standard deviation of 0.05
# R-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.240 with a standard deviation of 0.03
# Talker SVC accuracy: 0.250 with a standard deviation of 0.08
# Permutation test score: 0.235 with a standard deviation of 0.05
# FLT07
# L-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.312 with a standard deviation of 0.07
# Talker SVC accuracy: 0.229 with a standard deviation of 0.06
# Permutation test score: 0.239 with a standard deviation of 0.04
# L-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.323 with a standard deviation of 0.05
# Talker SVC accuracy: 0.271 with a standard deviation of 0.05
# Permutation test score: 0.245 with a standard deviation of 0.05
# L-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.354 with a standard deviation of 0.11
# Talker SVC accuracy: 0.271 with a standard deviation of 0.05
# Permutation test score: 0.228 with a standard deviation of 0.06
# L-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.333 with a standard deviation of 0.15
# Talker SVC accuracy: 0.250 with a standard deviation of 0.05
# Permutation test score: 0.216 with a standard deviation of 0.05
# R-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.313 with a standard deviation of 0.06
# Talker SVC accuracy: 0.333 with a standard deviation of 0.06
# Permutation test score: 0.233 with a standard deviation of 0.05
# R-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.385 with a standard deviation of 0.14
# Talker SVC accuracy: 0.208 with a standard deviation of 0.05
# Permutation test score: 0.231 with a standard deviation of 0.05
# R-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.354 with a standard deviation of 0.10
# Talker SVC accuracy: 0.354 with a standard deviation of 0.07
# Permutation test score: 0.223 with a standard deviation of 0.06
# R-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.427 with a standard deviation of 0.11
# Talker SVC accuracy: 0.312 with a standard deviation of 0.02
# Permutation test score: 0.218 with a standard deviation of 0.05
# FLT08
# L-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.385 with a standard deviation of 0.12
# Talker SVC accuracy: 0.281 with a standard deviation of 0.03
# Permutation test score: 0.238 with a standard deviation of 0.06
# L-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.312 with a standard deviation of 0.06
# Talker SVC accuracy: 0.260 with a standard deviation of 0.05
# Permutation test score: 0.257 with a standard deviation of 0.05
# L-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.375 with a standard deviation of 0.07
# Talker SVC accuracy: 0.229 with a standard deviation of 0.06
# Permutation test score: 0.229 with a standard deviation of 0.04
# L-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.438 with a standard deviation of 0.06
# Talker SVC accuracy: 0.292 with a standard deviation of 0.04
# Permutation test score: 0.241 with a standard deviation of 0.05
# R-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.219 with a standard deviation of 0.12
# Talker SVC accuracy: 0.260 with a standard deviation of 0.05
# Permutation test score: 0.241 with a standard deviation of 0.05
# R-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.146 with a standard deviation of 0.05
# Talker SVC accuracy: 0.302 with a standard deviation of 0.05
# Permutation test score: 0.242 with a standard deviation of 0.05
# R-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.354 with a standard deviation of 0.05
# Talker SVC accuracy: 0.260 with a standard deviation of 0.03
# Permutation test score: 0.226 with a standard deviation of 0.04
# R-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.323 with a standard deviation of 0.14
# Talker SVC accuracy: 0.219 with a standard deviation of 0.06
# Permutation test score: 0.226 with a standard deviation of 0.05
# FLT10
# L-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.281 with a standard deviation of 0.16
# Talker SVC accuracy: 0.260 with a standard deviation of 0.05
# Permutation test score: 0.227 with a standard deviation of 0.05
# L-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.208 with a standard deviation of 0.05
# Talker SVC accuracy: 0.250 with a standard deviation of 0.05
# Permutation test score: 0.243 with a standard deviation of 0.05
# L-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.260 with a standard deviation of 0.05
# Talker SVC accuracy: 0.188 with a standard deviation of 0.02
# Permutation test score: 0.235 with a standard deviation of 0.04
# L-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.396 with a standard deviation of 0.06
# Talker SVC accuracy: 0.260 with a standard deviation of 0.09
# Permutation test score: 0.219 with a standard deviation of 0.04
# R-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.198 with a standard deviation of 0.06
# Talker SVC accuracy: 0.219 with a standard deviation of 0.03
# Permutation test score: 0.240 with a standard deviation of 0.05
# R-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.281 with a standard deviation of 0.07
# Talker SVC accuracy: 0.302 with a standard deviation of 0.05
# Permutation test score: 0.242 with a standard deviation of 0.05
# R-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.385 with a standard deviation of 0.10
# Talker SVC accuracy: 0.260 with a standard deviation of 0.03
# Permutation test score: 0.224 with a standard deviation of 0.05
# R-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.271 with a standard deviation of 0.14
# Talker SVC accuracy: 0.302 with a standard deviation of 0.05
# Permutation test score: 0.249 with a standard deviation of 0.04
# FLT02
# L-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.281 with a standard deviation of 0.02
# Talker SVC accuracy: 0.198 with a standard deviation of 0.03
# Permutation test score: 0.243 with a standard deviation of 0.05
# L-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.354 with a standard deviation of 0.06
# Talker SVC accuracy: 0.260 with a standard deviation of 0.06
# Permutation test score: 0.235 with a standard deviation of 0.05
# L-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.396 with a standard deviation of 0.10
# Talker SVC accuracy: 0.198 with a standard deviation of 0.05
# Permutation test score: 0.233 with a standard deviation of 0.05
# L-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.323 with a standard deviation of 0.08
# Talker SVC accuracy: 0.219 with a standard deviation of 0.02
# Permutation test score: 0.228 with a standard deviation of 0.05
# R-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.219 with a standard deviation of 0.02
# Talker SVC accuracy: 0.219 with a standard deviation of 0.02
# Permutation test score: 0.249 with a standard deviation of 0.05
# R-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.406 with a standard deviation of 0.09
# Talker SVC accuracy: 0.260 with a standard deviation of 0.05
# Permutation test score: 0.247 with a standard deviation of 0.05
# R-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.323 with a standard deviation of 0.09
# Talker SVC accuracy: 0.219 with a standard deviation of 0.07
# Permutation test score: 0.234 with a standard deviation of 0.05
# R-MGN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.219 with a standard deviation of 0.09
# Talker SVC accuracy: 0.229 with a standard deviation of 0.07
# Permutation test score: 0.221 with a standard deviation of 0.05
# FLT04
# L-CN
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.250 with a standard deviation of 0.07
# Talker SVC accuracy: 0.302 with a standard deviation of 0.08
# Permutation test score: 0.244 with a standard deviation of 0.06
# L-SOC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.365 with a standard deviation of 0.05
# Talker SVC accuracy: 0.333 with a standard deviation of 0.09
# Permutation test score: 0.243 with a standard deviation of 0.05
# L-IC
# # of stat maps:  96
# /bgfs/bchandrasekaran/krs228/software/miniconda3/envs/py3/lib/python3.9/site-packages/nilearn/image/image.py:211: UserWarning: The parameter 'fwhm' for smoothing is specified as 0. Setting it to None (no smoothing will be performed)
#   warnings.warn("The parameter 'fwhm' for smoothing is specified "
# Tone SVC accuracy: 0.271 with a standard deviation of 0.06
# Talker SVC accuracy: 0.240 with a standard deviation of 0.05
# Permutation test score: 0.233 with a standard deviation of 0.06
# L-MGN
# # of stat maps:  96

# %%
'''
np.save('cv_list_tone', cv_list_tone)
np.save('cv_list_talker', cv_list_talker)
np.save('cv_list_null', cv_list_null)
np.save('sub_list', sub_list)
np.save('roi_list', roi_list)
'''

# %%
import pandas as pd

# %%
pd.DataFrame(data=cv_list_tone)
# Out:
#                                                    0   \
# 0                         [0.25, 0.1875, 0.25, 0.375]
# 1             [0.4583333333333333, 0.375, 0.5, 0.625]
# 2   [0.4166666666666667, 0.5833333333333334, 0.541...
# 3   [0.375, 0.375, 0.7083333333333334, 0.333333333...
# 4   [0.3333333333333333, 0.3333333333333333, 0.5, ...
# 5   [0.5416666666666666, 0.5, 0.4583333333333333, ...
# 6   [0.20833333333333334, 0.25, 0.5416666666666666...
# 7   [0.20833333333333334, 0.375, 0.208333333333333...
# 8   [0.20833333333333334, 0.20833333333333334, 0.4...
# 9             [0.375, 0.5, 0.4166666666666667, 0.375]
# 10  [0.2916666666666667, 0.375, 0.4166666666666667...
# 11  [0.375, 0.25, 0.5416666666666666, 0.3333333333...
# 12  [0.4166666666666667, 0.3333333333333333, 0.5, ...
#
#                                                    1   \
# 0                        [0.125, 0.1875, 0.25, 0.375]
# 1   [0.5, 0.5416666666666666, 0.5, 0.5833333333333...
# 2   [0.375, 0.3333333333333333, 0.5416666666666666...
# 3   [0.4583333333333333, 0.4583333333333333, 0.583...
# 4           [0.375, 0.375, 0.375, 0.4166666666666667]
# 5   [0.5, 0.5416666666666666, 0.5833333333333334, ...
# 6   [0.20833333333333334, 0.2916666666666667, 0.45...
# 7   [0.16666666666666666, 0.4166666666666667, 0.29...
# 8             [0.25, 0.25, 0.375, 0.3333333333333333]
# 9   [0.3333333333333333, 0.25, 0.5416666666666666,...
# 10  [0.3333333333333333, 0.4166666666666667, 0.458...
# 11  [0.375, 0.4583333333333333, 0.5416666666666666...
# 12  [0.3333333333333333, 0.125, 0.5, 0.41666666666...
#
#                                                    2   \
# 0                           [0.25, 0.25, 0.25, 0.375]
# 1   [0.625, 0.4583333333333333, 0.5416666666666666...
# 2   [0.4583333333333333, 0.5833333333333334, 0.5, ...
# 3   [0.20833333333333334, 0.4583333333333333, 0.5,...
# 4   [0.3333333333333333, 0.20833333333333334, 0.33...
# 5   [0.375, 0.5833333333333334, 0.5, 0.54166666666...
# 6   [0.16666666666666666, 0.25, 0.5416666666666666...
# 7   [0.2916666666666667, 0.2916666666666667, 0.5, ...
# 8   [0.25, 0.2916666666666667, 0.2916666666666667,...
# 9   [0.2916666666666667, 0.3333333333333333, 0.333...
# 10  [0.20833333333333334, 0.2916666666666667, 0.37...
# 11  [0.375, 0.375, 0.2916666666666667, 0.291666666...
# 12  [0.5, 0.4166666666666667, 0.5833333333333334, ...
#
#                                                    3   \
# 0                          [0.3125, 0.5, 0.25, 0.375]
# 1   [0.5, 0.4166666666666667, 0.4583333333333333, ...
# 2   [0.5, 0.6666666666666666, 0.5416666666666666, ...
# 3   [0.5416666666666666, 0.625, 0.4166666666666667...
# 4   [0.375, 0.16666666666666666, 0.333333333333333...
# 5   [0.375, 0.6666666666666666, 0.4583333333333333...
# 6                          [0.25, 0.25, 0.625, 0.375]
# 7   [0.375, 0.25, 0.4583333333333333, 0.2916666666...
# 8   [0.20833333333333334, 0.2916666666666667, 0.33...
# 9   [0.4166666666666667, 0.3333333333333333, 0.541...
# 10  [0.08333333333333333, 0.25, 0.4583333333333333...
# 11  [0.3333333333333333, 0.3333333333333333, 0.208...
# 12           [0.375, 0.25, 0.5416666666666666, 0.375]
#
#                                                    4   \
# 0                       [0.3125, 0.375, 0.25, 0.3125]
# 1   [0.5833333333333334, 0.4583333333333333, 0.541...
# 2   [0.5, 0.5416666666666666, 0.5416666666666666, ...
# 3   [0.4166666666666667, 0.4583333333333333, 0.5, ...
# 4   [0.4166666666666667, 0.25, 0.4583333333333333,...
# 5   [0.5, 0.4166666666666667, 0.375, 0.45833333333...
# 6   [0.2916666666666667, 0.20833333333333334, 0.58...
# 7   [0.2916666666666667, 0.16666666666666666, 0.33...
# 8   [0.25, 0.16666666666666666, 0.2916666666666667...
# 9   [0.4583333333333333, 0.3333333333333333, 0.416...
# 10  [0.16666666666666666, 0.20833333333333334, 0.4...
# 11  [0.3333333333333333, 0.3333333333333333, 0.625...
# 12  [0.4166666666666667, 0.375, 0.3333333333333333...
#
#                                                    5   \
# 0                       [0.25, 0.375, 0.1875, 0.5625]
# 1   [0.5, 0.4583333333333333, 0.4166666666666667, ...
# 2   [0.4583333333333333, 0.5833333333333334, 0.5, ...
# 3               [0.375, 0.5, 0.5416666666666666, 0.5]
# 4   [0.3333333333333333, 0.3333333333333333, 0.5, ...
# 5   [0.4583333333333333, 0.375, 0.625, 0.458333333...
# 6   [0.16666666666666666, 0.20833333333333334, 0.5...
# 7   [0.3333333333333333, 0.4166666666666667, 0.458...
# 8           [0.20833333333333334, 0.25, 0.375, 0.375]
# 9   [0.375, 0.25, 0.4583333333333333, 0.4583333333...
# 10             [0.25, 0.375, 0.5, 0.5833333333333334]
# 11  [0.4166666666666667, 0.4583333333333333, 0.5, ...
# 12  [0.4166666666666667, 0.375, 0.5, 0.45833333333...
#
#                                                    6   \
# 0                           [0.1875, 0.25, 0.25, 0.0]
# 1   [0.4166666666666667, 0.4166666666666667, 0.375...
# 2   [0.4583333333333333, 0.6666666666666666, 0.541...
# 3   [0.625, 0.4166666666666667, 0.6666666666666666...
# 4   [0.4166666666666667, 0.3333333333333333, 0.416...
# 5   [0.5416666666666666, 0.5416666666666666, 0.5, ...
# 6             [0.25, 0.25, 0.625, 0.5833333333333334]
# 7   [0.2916666666666667, 0.125, 0.2083333333333333...
# 8   [0.16666666666666666, 0.2916666666666667, 0.37...
# 9   [0.25, 0.2916666666666667, 0.4583333333333333,...
# 10  [0.3333333333333333, 0.4166666666666667, 0.458...
# 11  [0.4583333333333333, 0.4166666666666667, 0.625...
# 12                         [0.375, 0.375, 0.375, 0.5]
#
#                                                    7   \
# 0                        [0.25, 0.0625, 0.25, 0.3125]
# 1   [0.5, 0.4583333333333333, 0.625, 0.45833333333...
# 2   [0.4583333333333333, 0.5416666666666666, 0.666...
# 3           [0.375, 0.375, 0.375, 0.4166666666666667]
# 4   [0.4166666666666667, 0.4166666666666667, 0.416...
# 5   [0.4583333333333333, 0.5833333333333334, 0.541...
# 6   [0.2916666666666667, 0.25, 0.5416666666666666,...
# 7   [0.20833333333333334, 0.3333333333333333, 0.25...
# 8             [0.25, 0.25, 0.375, 0.3333333333333333]
# 9   [0.375, 0.2916666666666667, 0.4583333333333333...
# 10  [0.25, 0.4583333333333333, 0.4583333333333333,...
# 11  [0.375, 0.3333333333333333, 0.3333333333333333...
# 12  [0.375, 0.2916666666666667, 0.4583333333333333...
#
#                                                    8   \
# 0                      [0.25, 0.1875, 0.4375, 0.1875]
# 1   [0.6666666666666666, 0.4166666666666667, 0.666...
# 2   [0.4166666666666667, 0.3333333333333333, 0.541...
# 3   [0.2916666666666667, 0.3333333333333333, 0.5, ...
# 4   [0.2916666666666667, 0.375, 0.4166666666666667...
# 5   [0.4166666666666667, 0.5416666666666666, 0.416...
# 6   [0.08333333333333333, 0.20833333333333334, 0.5...
# 7   [0.20833333333333334, 0.4166666666666667, 0.37...
# 8   [0.20833333333333334, 0.375, 0.333333333333333...
# 9   [0.2916666666666667, 0.375, 0.4166666666666667...
# 10  [0.16666666666666666, 0.16666666666666666, 0.5...
# 11  [0.375, 0.4166666666666667, 0.4583333333333333...
# 12  [0.4583333333333333, 0.4583333333333333, 0.416...
#
#                                                    9   \
# 0                         [0.25, 0.375, 0.25, 0.1875]
# 1   [0.5416666666666666, 0.5, 0.4583333333333333, ...
# 2   [0.375, 0.5833333333333334, 0.4583333333333333...
# 3   [0.2916666666666667, 0.4583333333333333, 0.5, ...
# 4              [0.25, 0.3333333333333333, 0.375, 0.5]
# 5   [0.4583333333333333, 0.4166666666666667, 0.416...
# 6   [0.125, 0.16666666666666666, 0.5, 0.4583333333...
# 7   [0.16666666666666666, 0.2916666666666667, 0.20...
# 8   [0.25, 0.2916666666666667, 0.2916666666666667,...
# 9   [0.20833333333333334, 0.25, 0.375, 0.291666666...
# 10  [0.3333333333333333, 0.20833333333333334, 0.41...
# 11  [0.2916666666666667, 0.5, 0.4166666666666667, ...
# 12  [0.2916666666666667, 0.2916666666666667, 0.333...
#
#                                                    10  \
# 0                       [0.125, 0.375, 0.0625, 0.125]
# 1   [0.5, 0.6666666666666666, 0.4166666666666667, ...
# 2   [0.4583333333333333, 0.4583333333333333, 0.458...
# 3   [0.4583333333333333, 0.5, 0.5416666666666666, ...
# 4   [0.2916666666666667, 0.16666666666666666, 0.33...
# 5   [0.4166666666666667, 0.4166666666666667, 0.458...
# 6   [0.20833333333333334, 0.16666666666666666, 0.5...
# 7   [0.20833333333333334, 0.20833333333333334, 0.4...
# 8               [0.25, 0.25, 0.2916666666666667, 0.5]
# 9   [0.375, 0.25, 0.20833333333333334, 0.208333333...
# 10  [0.16666666666666666, 0.2916666666666667, 0.45...
# 11  [0.4166666666666667, 0.3333333333333333, 0.375...
# 12  [0.5, 0.4166666666666667, 0.4583333333333333, ...
#
#                                                    11
# 0                         [0.25, 0.1875, 0.3125, 0.5]
# 1   [0.5, 0.5833333333333334, 0.4583333333333333, ...
# 2   [0.4583333333333333, 0.4583333333333333, 0.541...
# 3           [0.375, 0.4583333333333333, 0.625, 0.375]
# 4   [0.375, 0.4166666666666667, 0.3333333333333333...
# 5   [0.5416666666666666, 0.4166666666666667, 0.625...
# 6   [0.20833333333333334, 0.20833333333333334, 0.6...
# 7            [0.375, 0.25, 0.4166666666666667, 0.375]
# 8   [0.20833333333333334, 0.3333333333333333, 0.33...
# 9   [0.375, 0.3333333333333333, 0.5, 0.41666666666...
# 10  [0.3333333333333333, 0.3333333333333333, 0.541...
# 11  [0.375, 0.5, 0.5416666666666666, 0.41666666666...
# 12  [0.2916666666666667, 0.25, 0.4583333333333333,...

# %% [markdown]
# ## Train expert, test learner

# %%
import os
import numpy as np
from copy import copy
from glob import glob
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, accuracy_score

# %%
sub_list_mand = ['FLT03', 'FLT05', 'FLT07', 'FLT08', 'FLT10', ] # 'FLT01', 

sub_list_nman = ['FLT02', 'FLT04', 'FLT06', 'FLT09', 'FLT11', 'FLT12', 'FLT13', ]

sub_list = sub_list_mand + sub_list_nman
print(sub_list)
# Out:
# ['FLT03', 'FLT05', 'FLT07', 'FLT08', 'FLT10', 'FLT02', 'FLT04', 'FLT06', 'FLT09', 'FLT11', 'FLT12', 'FLT13']

# %%
roi_list = ['L-Caud', 'L-Put', 'R-Caud', 'R-Put']

# %%
fwhm_sub = 1.50
space_label = 'MNI152NLin2009cAsym'
nilearn_dir = os.path.join('/bgfs/bchandrasekaran/krs228/data/FLT/',
                         'data_bids_noIntendedFor/derivatives/nilearn/')
deriv_dir = os.path.join(nilearn_dir, 'level-1_fwhm-1.50')

# %%
# training data
mand_data = []
for sub_id in sub_list_mand:
    nilearn_sub_dir = os.path.join(deriv_dir,
                                   'sub-%s_space-%s'%(sub_id, space_label))

    stat_maps = sorted(glob(nilearn_sub_dir+'/stimulus_per_run'+'/run*/*di*nii.gz')) # run-specific stimulus beta maps
    
    mand_data=mand_data+stat_maps

# %%
# test data
nman_data = []
for sub_id in sub_list_nman:
    nilearn_sub_dir = os.path.join(deriv_dir,
                                   'sub-%s_space-%s'%(sub_id, space_label))

    stat_maps = sorted(glob(nilearn_sub_dir+'/stimulus_per_run'+'/run*/*di*nii.gz')) # run-specific stimulus beta maps
    
    nman_data=nman_data+stat_maps

# %%
cv_list_tone = []
cv_list_talker = []
cv_list_null = []

sub_gen = 'FLT10'
for mask_descrip in roi_list:
    # define the mask for the region of interest
    print(mask_descrip)
    masks_dir = os.path.join(nilearn_dir, 'masks', 'sub-%s'%sub_gen, 'space-%s'%space_label, 'masks-dseg', )
    mask_fpath = os.path.join(masks_dir, 'sub-%s_space-%s_mask-%s.nii.gz'%(sub_gen, space_label, mask_descrip))
    
    # generating training data and labels
    print('training set length: ', len(mand_data))
    X_train, train_masker = mask_fmri(mand_data, mask_fpath, fwhm_sub)
    train_conditions_tone, train_conditions_talker, train_conditions_all, train_conditions_shuffled = create_labels(mand_data)
    y_train = copy(train_conditions_tone)
          
    print('initializing classifier')
    clf = svm.SVC(decision_function_shape='ovo').fit(X_train, y_train)
    
    print('cross-validating the training set')
    cv_scores = cross_val_score(clf, X_train, y_train, cv=StratifiedKFold(n_splits=4))
    print('cross-validation score = ', cv_scores.mean())

    for sub_id in sub_list_nman:
        print(sub_id)
        # generating test data and labels
        nilearn_sub_dir = os.path.join(deriv_dir, 'sub-%s_space-%s'%(sub_id, space_label))
        
        for rx, run_dir in enumerate(sorted(glob(nilearn_sub_dir+'/stimulus_per_run'+'/run*'))):
            run_label = os.path.basename(run_dir)
            print(run_label)
            stat_maps = sorted(glob(run_dir+'/*di*nii.gz'))

            masks_dir = os.path.join(nilearn_dir, 'masks', 'sub-%s'%sub_id, 'space-%s'%space_label, 'masks-dseg', )
            mask_fpath = os.path.join(masks_dir, 'sub-%s_space-%s_mask-%s.nii.gz'%(sub_id, space_label, mask_descrip))

            print('test set length: ', len(stat_maps))
            X_test, test_masker = mask_fmri(stat_maps, mask_fpath, fwhm_sub)
            test_conditions_tone, test_conditions_talker, test_conditions_all, test_conditions_shuffled = create_labels(stat_maps)
            y_test = copy(test_conditions_tone)

            # Run classifier
            y_pred = clf.predict(X_test)

            clf_acc = accuracy_score(y_test, y_pred)
            print('sub-{} run-{} mask-{} accuracy: '.format(sub_id, run_label, mask_descrip), clf_acc)

            # append subject cv scores to overall list
            cv_list_tone.append(clf_acc)
# Out:
# L-Caud
# training set length:  480
# initializing classifier
# cross-validating the training set
# cross-validation score =  0.3
# FLT02
# run00
# test set length:  16
# sub-FLT02 run-run00 mask-L-Caud accuracy:  0.3125
# run01
# test set length:  16
# sub-FLT02 run-run01 mask-L-Caud accuracy:  0.3125
# run02
# test set length:  16
# sub-FLT02 run-run02 mask-L-Caud accuracy:  0.1875
# run03
# test set length:  16
# sub-FLT02 run-run03 mask-L-Caud accuracy:  0.1875
# run04
# test set length:  16
# sub-FLT02 run-run04 mask-L-Caud accuracy:  0.1875
# run05
# test set length:  16
# sub-FLT02 run-run05 mask-L-Caud accuracy:  0.3125
# FLT04
# run00
# test set length:  16
# sub-FLT04 run-run00 mask-L-Caud accuracy:  0.25
# run01
# test set length:  16
# sub-FLT04 run-run01 mask-L-Caud accuracy:  0.125
# run02
# test set length:  16
# sub-FLT04 run-run02 mask-L-Caud accuracy:  0.25
# run03
# test set length:  16
# sub-FLT04 run-run03 mask-L-Caud accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT04 run-run04 mask-L-Caud accuracy:  0.1875
# run05
# test set length:  16
# sub-FLT04 run-run05 mask-L-Caud accuracy:  0.0
# FLT06
# run00
# test set length:  16
# sub-FLT06 run-run00 mask-L-Caud accuracy:  0.25
# run01
# test set length:  16
# sub-FLT06 run-run01 mask-L-Caud accuracy:  0.25
# run02
# test set length:  16
# sub-FLT06 run-run02 mask-L-Caud accuracy:  0.1875
# run03
# test set length:  16
# sub-FLT06 run-run03 mask-L-Caud accuracy:  0.25
# run04
# test set length:  16
# sub-FLT06 run-run04 mask-L-Caud accuracy:  0.125
# run05
# test set length:  16
# sub-FLT06 run-run05 mask-L-Caud accuracy:  0.125
# FLT09
# run00
# test set length:  16
# sub-FLT09 run-run00 mask-L-Caud accuracy:  0.25
# run01
# test set length:  16
# sub-FLT09 run-run01 mask-L-Caud accuracy:  0.0625
# run02
# test set length:  16
# sub-FLT09 run-run02 mask-L-Caud accuracy:  0.0625
# run03
# test set length:  16
# sub-FLT09 run-run03 mask-L-Caud accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT09 run-run04 mask-L-Caud accuracy:  0.3125
# run05
# test set length:  16
# sub-FLT09 run-run05 mask-L-Caud accuracy:  0.125
# FLT11
# run00
# test set length:  16
# sub-FLT11 run-run00 mask-L-Caud accuracy:  0.125
# run01
# test set length:  16
# sub-FLT11 run-run01 mask-L-Caud accuracy:  0.25
# run02
# test set length:  16
# sub-FLT11 run-run02 mask-L-Caud accuracy:  0.1875
# run03
# test set length:  16
# sub-FLT11 run-run03 mask-L-Caud accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT11 run-run04 mask-L-Caud accuracy:  0.125
# run05
# test set length:  16
# sub-FLT11 run-run05 mask-L-Caud accuracy:  0.5625
# FLT12
# run00
# test set length:  16
# sub-FLT12 run-run00 mask-L-Caud accuracy:  0.3125
# run01
# test set length:  16
# sub-FLT12 run-run01 mask-L-Caud accuracy:  0.125
# run02
# test set length:  16
# sub-FLT12 run-run02 mask-L-Caud accuracy:  0.1875
# run03
# test set length:  16
# sub-FLT12 run-run03 mask-L-Caud accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT12 run-run04 mask-L-Caud accuracy:  0.125
# run05
# test set length:  16
# sub-FLT12 run-run05 mask-L-Caud accuracy:  0.1875
# FLT13
# run00
# test set length:  16
# sub-FLT13 run-run00 mask-L-Caud accuracy:  0.25
# run01
# test set length:  16
# sub-FLT13 run-run01 mask-L-Caud accuracy:  0.25
# run02
# test set length:  16
# sub-FLT13 run-run02 mask-L-Caud accuracy:  0.125
# run03
# test set length:  16
# sub-FLT13 run-run03 mask-L-Caud accuracy:  0.1875
# run04
# test set length:  16
# sub-FLT13 run-run04 mask-L-Caud accuracy:  0.125
# run05
# test set length:  16
# sub-FLT13 run-run05 mask-L-Caud accuracy:  0.125
# L-Put
# training set length:  480
# initializing classifier
# cross-validating the training set
# cross-validation score =  0.28750000000000003
# FLT02
# run00
# test set length:  16
# sub-FLT02 run-run00 mask-L-Put accuracy:  0.0625
# run01
# test set length:  16
# sub-FLT02 run-run01 mask-L-Put accuracy:  0.375
# run02
# test set length:  16
# sub-FLT02 run-run02 mask-L-Put accuracy:  0.25
# run03
# test set length:  16
# sub-FLT02 run-run03 mask-L-Put accuracy:  0.5
# run04
# test set length:  16
# sub-FLT02 run-run04 mask-L-Put accuracy:  0.1875
# run05
# test set length:  16
# sub-FLT02 run-run05 mask-L-Put accuracy:  0.3125
# FLT04
# run00
# test set length:  16
# sub-FLT04 run-run00 mask-L-Put accuracy:  0.25
# run01
# test set length:  16
# sub-FLT04 run-run01 mask-L-Put accuracy:  0.125
# run02
# test set length:  16
# sub-FLT04 run-run02 mask-L-Put accuracy:  0.125
# run03
# test set length:  16
# sub-FLT04 run-run03 mask-L-Put accuracy:  0.25
# run04
# test set length:  16
# sub-FLT04 run-run04 mask-L-Put accuracy:  0.375
# run05
# test set length:  16
# sub-FLT04 run-run05 mask-L-Put accuracy:  0.0625
# FLT06
# run00
# test set length:  16
# sub-FLT06 run-run00 mask-L-Put accuracy:  0.1875
# run01
# test set length:  16
# sub-FLT06 run-run01 mask-L-Put accuracy:  0.0625
# run02
# test set length:  16
# sub-FLT06 run-run02 mask-L-Put accuracy:  0.25
# run03
# test set length:  16
# sub-FLT06 run-run03 mask-L-Put accuracy:  0.0625
# run04
# test set length:  16
# sub-FLT06 run-run04 mask-L-Put accuracy:  0.0625
# run05
# test set length:  16
# sub-FLT06 run-run05 mask-L-Put accuracy:  0.25
# FLT09
# run00
# test set length:  16
# sub-FLT09 run-run00 mask-L-Put accuracy:  0.3125
# run01
# test set length:  16
# sub-FLT09 run-run01 mask-L-Put accuracy:  0.375
# run02
# test set length:  16
# sub-FLT09 run-run02 mask-L-Put accuracy:  0.1875
# run03
# test set length:  16
# sub-FLT09 run-run03 mask-L-Put accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT09 run-run04 mask-L-Put accuracy:  0.3125
# run05
# test set length:  16
# sub-FLT09 run-run05 mask-L-Put accuracy:  0.125
# FLT11
# run00
# test set length:  16
# sub-FLT11 run-run00 mask-L-Put accuracy:  0.1875
# run01
# test set length:  16
# sub-FLT11 run-run01 mask-L-Put accuracy:  0.3125
# run02
# test set length:  16
# sub-FLT11 run-run02 mask-L-Put accuracy:  0.4375
# run03
# test set length:  16
# sub-FLT11 run-run03 mask-L-Put accuracy:  0.375
# run04
# test set length:  16
# sub-FLT11 run-run04 mask-L-Put accuracy:  0.375
# run05
# test set length:  16
# sub-FLT11 run-run05 mask-L-Put accuracy:  0.4375
# FLT12
# run00
# test set length:  16
# sub-FLT12 run-run00 mask-L-Put accuracy:  0.3125
# run01
# test set length:  16
# sub-FLT12 run-run01 mask-L-Put accuracy:  0.5
# run02
# test set length:  16
# sub-FLT12 run-run02 mask-L-Put accuracy:  0.5
# run03
# test set length:  16
# sub-FLT12 run-run03 mask-L-Put accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT12 run-run04 mask-L-Put accuracy:  0.4375
# run05
# test set length:  16
# sub-FLT12 run-run05 mask-L-Put accuracy:  0.1875
# FLT13
# run00
# test set length:  16
# sub-FLT13 run-run00 mask-L-Put accuracy:  0.25
# run01
# test set length:  16
# sub-FLT13 run-run01 mask-L-Put accuracy:  0.1875
# run02
# test set length:  16
# sub-FLT13 run-run02 mask-L-Put accuracy:  0.25
# run03
# test set length:  16
# sub-FLT13 run-run03 mask-L-Put accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT13 run-run04 mask-L-Put accuracy:  0.125
# run05
# test set length:  16
# sub-FLT13 run-run05 mask-L-Put accuracy:  0.125
# R-Caud
# training set length:  480
# initializing classifier
# cross-validating the training set
# cross-validation score =  0.23749999999999996
# FLT02
# run00
# test set length:  16
# sub-FLT02 run-run00 mask-R-Caud accuracy:  0.25
# run01
# test set length:  16
# sub-FLT02 run-run01 mask-R-Caud accuracy:  0.5
# run02
# test set length:  16
# sub-FLT02 run-run02 mask-R-Caud accuracy:  0.25
# run03
# test set length:  16
# sub-FLT02 run-run03 mask-R-Caud accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT02 run-run04 mask-R-Caud accuracy:  0.6875
# run05
# test set length:  16
# sub-FLT02 run-run05 mask-R-Caud accuracy:  0.4375
# FLT04
# run00
# test set length:  16
# sub-FLT04 run-run00 mask-R-Caud accuracy:  0.125
# run01
# test set length:  16
# sub-FLT04 run-run01 mask-R-Caud accuracy:  0.375
# run02
# test set length:  16
# sub-FLT04 run-run02 mask-R-Caud accuracy:  0.25
# run03
# test set length:  16
# sub-FLT04 run-run03 mask-R-Caud accuracy:  0.0
# run04
# test set length:  16
# sub-FLT04 run-run04 mask-R-Caud accuracy:  0.125
# run05
# test set length:  16
# sub-FLT04 run-run05 mask-R-Caud accuracy:  0.375
# FLT06
# run00
# test set length:  16
# sub-FLT06 run-run00 mask-R-Caud accuracy:  0.25
# run01
# test set length:  16
# sub-FLT06 run-run01 mask-R-Caud accuracy:  0.25
# run02
# test set length:  16
# sub-FLT06 run-run02 mask-R-Caud accuracy:  0.3125
# run03
# test set length:  16
# sub-FLT06 run-run03 mask-R-Caud accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT06 run-run04 mask-R-Caud accuracy:  0.1875
# run05
# test set length:  16
# sub-FLT06 run-run05 mask-R-Caud accuracy:  0.125
# FLT09
# run00
# test set length:  16
# sub-FLT09 run-run00 mask-R-Caud accuracy:  0.375
# run01
# test set length:  16
# sub-FLT09 run-run01 mask-R-Caud accuracy:  0.0625
# run02
# test set length:  16
# sub-FLT09 run-run02 mask-R-Caud accuracy:  0.1875
# run03
# test set length:  16
# sub-FLT09 run-run03 mask-R-Caud accuracy:  0.1875
# run04
# test set length:  16
# sub-FLT09 run-run04 mask-R-Caud accuracy:  0.0625
# run05
# test set length:  16
# sub-FLT09 run-run05 mask-R-Caud accuracy:  0.1875
# FLT11
# run00
# test set length:  16
# sub-FLT11 run-run00 mask-R-Caud accuracy:  0.25
# run01
# test set length:  16
# sub-FLT11 run-run01 mask-R-Caud accuracy:  0.3125
# run02
# test set length:  16
# sub-FLT11 run-run02 mask-R-Caud accuracy:  0.125
# run03
# test set length:  16
# sub-FLT11 run-run03 mask-R-Caud accuracy:  0.375
# run04
# test set length:  16
# sub-FLT11 run-run04 mask-R-Caud accuracy:  0.125
# run05
# test set length:  16
# sub-FLT11 run-run05 mask-R-Caud accuracy:  0.375
# FLT12
# run00
# test set length:  16
# sub-FLT12 run-run00 mask-R-Caud accuracy:  0.1875
# run01
# test set length:  16
# sub-FLT12 run-run01 mask-R-Caud accuracy:  0.25
# run02
# test set length:  16
# sub-FLT12 run-run02 mask-R-Caud accuracy:  0.125
# run03
# test set length:  16
# sub-FLT12 run-run03 mask-R-Caud accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT12 run-run04 mask-R-Caud accuracy:  0.375
# run05
# test set length:  16
# sub-FLT12 run-run05 mask-R-Caud accuracy:  0.5
# FLT13
# run00
# test set length:  16
# sub-FLT13 run-run00 mask-R-Caud accuracy:  0.1875
# run01
# test set length:  16
# sub-FLT13 run-run01 mask-R-Caud accuracy:  0.125
# run02
# test set length:  16
# sub-FLT13 run-run02 mask-R-Caud accuracy:  0.3125
# run03
# test set length:  16
# sub-FLT13 run-run03 mask-R-Caud accuracy:  0.125
# run04
# test set length:  16
# sub-FLT13 run-run04 mask-R-Caud accuracy:  0.125
# run05
# test set length:  16
# sub-FLT13 run-run05 mask-R-Caud accuracy:  0.1875
# R-Put
# training set length:  480
# initializing classifier
# cross-validating the training set
# cross-validation score =  0.25833333333333336
# FLT02
# run00
# test set length:  16
# sub-FLT02 run-run00 mask-R-Put accuracy:  0.3125
# run01
# test set length:  16
# sub-FLT02 run-run01 mask-R-Put accuracy:  0.25
# run02
# test set length:  16
# sub-FLT02 run-run02 mask-R-Put accuracy:  0.3125
# run03
# test set length:  16
# sub-FLT02 run-run03 mask-R-Put accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT02 run-run04 mask-R-Put accuracy:  0.25
# run05
# test set length:  16
# sub-FLT02 run-run05 mask-R-Put accuracy:  0.3125
# FLT04
# run00
# test set length:  16
# sub-FLT04 run-run00 mask-R-Put accuracy:  0.375
# run01
# test set length:  16
# sub-FLT04 run-run01 mask-R-Put accuracy:  0.25
# run02
# test set length:  16
# sub-FLT04 run-run02 mask-R-Put accuracy:  0.0625
# run03
# test set length:  16
# sub-FLT04 run-run03 mask-R-Put accuracy:  0.375
# run04
# test set length:  16
# sub-FLT04 run-run04 mask-R-Put accuracy:  0.125
# run05
# test set length:  16
# sub-FLT04 run-run05 mask-R-Put accuracy:  0.125
# FLT06
# run00
# test set length:  16
# sub-FLT06 run-run00 mask-R-Put accuracy:  0.25
# run01
# test set length:  16
# sub-FLT06 run-run01 mask-R-Put accuracy:  0.25
# run02
# test set length:  16
# sub-FLT06 run-run02 mask-R-Put accuracy:  0.375
# run03
# test set length:  16
# sub-FLT06 run-run03 mask-R-Put accuracy:  0.25
# run04
# test set length:  16
# sub-FLT06 run-run04 mask-R-Put accuracy:  0.25
# run05
# test set length:  16
# sub-FLT06 run-run05 mask-R-Put accuracy:  0.375
# FLT09
# run00
# test set length:  16
# sub-FLT09 run-run00 mask-R-Put accuracy:  0.0625
# run01
# test set length:  16
# sub-FLT09 run-run01 mask-R-Put accuracy:  0.25
# run02
# test set length:  16
# sub-FLT09 run-run02 mask-R-Put accuracy:  0.125
# run03
# test set length:  16
# sub-FLT09 run-run03 mask-R-Put accuracy:  0.1875
# run04
# test set length:  16
# sub-FLT09 run-run04 mask-R-Put accuracy:  0.1875
# run05
# test set length:  16
# sub-FLT09 run-run05 mask-R-Put accuracy:  0.0625
# FLT11
# run00
# test set length:  16
# sub-FLT11 run-run00 mask-R-Put accuracy:  0.3125
# run01
# test set length:  16
# sub-FLT11 run-run01 mask-R-Put accuracy:  0.3125
# run02
# test set length:  16
# sub-FLT11 run-run02 mask-R-Put accuracy:  0.375
# run03
# test set length:  16
# sub-FLT11 run-run03 mask-R-Put accuracy:  0.4375
# run04
# test set length:  16
# sub-FLT11 run-run04 mask-R-Put accuracy:  0.3125
# run05
# test set length:  16
# sub-FLT11 run-run05 mask-R-Put accuracy:  0.25
# FLT12
# run00
# test set length:  16
# sub-FLT12 run-run00 mask-R-Put accuracy:  0.125
# run01
# test set length:  16
# sub-FLT12 run-run01 mask-R-Put accuracy:  0.1875
# run02
# test set length:  16
# sub-FLT12 run-run02 mask-R-Put accuracy:  0.0625
# run03
# test set length:  16
# sub-FLT12 run-run03 mask-R-Put accuracy:  0.3125
# run04
# test set length:  16
# sub-FLT12 run-run04 mask-R-Put accuracy:  0.0
# run05
# test set length:  16
# sub-FLT12 run-run05 mask-R-Put accuracy:  0.3125
# FLT13
# run00
# test set length:  16
# sub-FLT13 run-run00 mask-R-Put accuracy:  0.1875
# run01
# test set length:  16
# sub-FLT13 run-run01 mask-R-Put accuracy:  0.25
# run02
# test set length:  16
# sub-FLT13 run-run02 mask-R-Put accuracy:  0.25
# run03
# test set length:  16
# sub-FLT13 run-run03 mask-R-Put accuracy:  0.375
# run04
# test set length:  16
# sub-FLT13 run-run04 mask-R-Put accuracy:  0.1875
# run05
# test set length:  16
# sub-FLT13 run-run05 mask-R-Put accuracy:  0.25
